# %% [markdown]
# # Exploratory Analysis — Presumptive Removal & Collateral Auditor
#
# Scratch space for inspecting the panel dataset produced by `src/econometrics/panel_builder.py`
# before committing to a specification in `src/econometrics/estimation.py`.
#
# Suggested sections:
# 1. Load `data/processed/*.parquet`
# 2. Cohort balance checks (treated vs. control, pre-T0)
# 3. Collateral Damage Ratio by month
# 4. Review Latency distribution, pre vs. post
# 5. Event-study coefficient plot (`fit_event_study`)

# %%
import duckdb
import pandas as pd

# con = duckdb.connect("data/processed/pr_auditor.duckdb")
# panel_df = con.execute("SELECT * FROM panel").df()
# panel_df.head()
